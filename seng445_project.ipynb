# %% [markdown]
# <a href="https://colab.research.google.com/github/elifabanoz/bone-fracture-classification/blob/main/seng445_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Course: Computer Vision
#Date: 20.12.2025

# %%
import numpy as np
import os
import warnings
warnings.filterwarnings('ignore')

# %%
#Tensorflow and Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
# Scikit-learn
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Set random seeds for reproducibility
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
# Configuration
IMG_SIZE = 224  # EfficientNetB0 default input size
BATCH_SIZE = 8  # Small batch size for small dataset
EPOCHS = 50
N_FOLDS = 10

# %%
# Data paths (Google Colab structure - same level as sample_data)
DATA_DIR = "data"
FRACTURE_DIR = os.path.join(DATA_DIR, "fracture")
NORMAL_DIR = os.path.join(DATA_DIR, "normal")

# %%
def load_and_preprocess_image(image_path, img_size=IMG_SIZE):
    """Load and preprocess a single image."""
    img = load_img(image_path, target_size=(img_size, img_size))
    img_array = img_to_array(img)
    return img_array

# %%
def load_dataset():
    """Load all images and labels from the dataset."""
    images = []
    labels = []

    # Load fracture images (label = 1)
    print("Loading fracture images...")
    if os.path.exists(FRACTURE_DIR):
        fracture_files = [f for f in os.listdir(FRACTURE_DIR)
                          if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif'))]
        for filename in fracture_files:
            filepath = os.path.join(FRACTURE_DIR, filename)
            try:
                img = load_and_preprocess_image(filepath)
                images.append(img)
                labels.append(1)  # Fracture = 1
            except Exception as e:
                print(f"Error loading {filepath}: {e}")
        print(f"  Loaded {len([l for l in labels if l == 1])} fracture images")
    else:
        raise FileNotFoundError(f"Fracture directory not found: {FRACTURE_DIR}")

    # Load normal images (label = 0)
    print("Loading normal images...")
    if os.path.exists(NORMAL_DIR):
        normal_files = [f for f in os.listdir(NORMAL_DIR)
                        if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif'))]
        for filename in normal_files:
            filepath = os.path.join(NORMAL_DIR, filename)
            try:
                img = load_and_preprocess_image(filepath)
                images.append(img)
                labels.append(0)  # Normal = 0
            except Exception as e:
                print(f"Error loading {filepath}: {e}")
        print(f"  Loaded {len([l for l in labels if l == 0])} normal images")
    else:
        raise FileNotFoundError(f"Normal directory not found: {NORMAL_DIR}")

    X = np.array(images, dtype=np.float32)
    y = np.array(labels, dtype=np.int32)

    print(f"\nDataset Summary:")
    print(f"  Total images: {len(X)}")
    print(f"  Fracture: {np.sum(y == 1)}, Normal: {np.sum(y == 0)}")
    print(f"  Image shape: {X[0].shape}")

    return X, y

# %%
def get_data_augmentation():
    """Create data augmentation generator for training."""
    return ImageDataGenerator(
        preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
        rotation_range=20,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=True,
        vertical_flip=False,
        zoom_range=0.15,
        shear_range=0.1,
        fill_mode='nearest'
    )

# %%
def get_validation_generator():
    """Create generator for validation (only preprocessing, no augmentation)."""
    return ImageDataGenerator(
        preprocessing_function=tf.keras.applications.efficientnet.preprocess_input
    )

# %%
def create_model(input_shape=(IMG_SIZE, IMG_SIZE, 3)):
    """
    Create transfer learning model using EfficientNetB0.

    Architecture:
    - EfficientNetB0 pretrained on ImageNet as feature extractor
    - Global Average Pooling
    - Dense layers with dropout for regularization
    - Sigmoid output for binary classification
    """
    # Load pretrained EfficientNetB0
    base_model = EfficientNetB0(
        weights='imagenet',
        include_top=False,
        input_shape=input_shape
    )

    # Build the model
    inputs = keras.Input(shape=input_shape)

    # Base model (feature extraction)
    x = base_model(inputs, training=False)

    # Classification head
    x = layers.GlobalAveragePooling2D(name='global_avg_pool')(x)
    x = layers.BatchNormalization(name='bn1')(x)
    x = layers.Dropout(0.4, name='dropout1')(x)
    x = layers.Dense(256, activation='relu', name='dense1')(x)
    x = layers.BatchNormalization(name='bn2')(x)
    x = layers.Dropout(0.3, name='dropout2')(x)
    x = layers.Dense(64, activation='relu', name='dense2')(x)
    x = layers.Dropout(0.2, name='dropout3')(x)
    outputs = layers.Dense(1, activation='sigmoid', name='output')(x)

    model = Model(inputs, outputs, name='FractureClassifier')

    return model, base_model

# %%
def train_fold(X_train, y_train, X_val, y_val, fold_num):
    """
    Train model for a single fold with two-phase training:
    Phase 1: Train only classification head (frozen base)
    Phase 2: Fine-tune top layers of base model
    """
    print(f"\n{'='*60}")
    print(f"FOLD {fold_num}/{N_FOLDS}")
    print(f"{'='*60}")
    print(f"Train: {len(X_train)} samples | Val: {len(X_val)} samples")
    print(f"Train distribution - Fracture: {np.sum(y_train==1)}, Normal: {np.sum(y_train==0)}")

    # Clear any previous session
    keras.backend.clear_session()

    # Create model
    model, base_model = create_model()

    # Freeze base model for phase 1
    base_model.trainable = False

    # Data generators
    train_datagen = get_data_augmentation()
    val_datagen = get_validation_generator()

    # Callbacks
    early_stop = EarlyStopping(
        monitor='val_accuracy',
        patience=8,
        restore_best_weights=True,
        verbose=1
    )

    reduce_lr = ReduceLROnPlateau(
        monitor='val_accuracy',
        factor=0.5,
        patience=4,
        min_lr=1e-7,
        verbose=1
    )

    # ==================== PHASE 1: Train Classification Head ====================
    print("\n[Phase 1] Training classification head (base frozen)...")

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-3),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    # Fit phase 1
    train_generator = train_datagen.flow(X_train, y_train, batch_size=BATCH_SIZE, seed=SEED)
    val_generator = val_datagen.flow(X_val, y_val, batch_size=BATCH_SIZE, shuffle=False)

    steps_per_epoch = max(1, len(X_train) // BATCH_SIZE)
    validation_steps = max(1, len(X_val) // BATCH_SIZE)

    model.fit(
        train_generator,
        steps_per_epoch=steps_per_epoch,
        epochs=15,
        validation_data=val_generator,
        validation_steps=validation_steps,
        callbacks=[early_stop, reduce_lr],
        verbose=1
    )

    # ==================== PHASE 2: Fine-tune Top Layers ====================
    print("\n[Phase 2] Fine-tuning top layers of base model...")

    # Unfreeze top layers of base model
    base_model.trainable = True

    # Freeze early layers, unfreeze last 30 layers
    for layer in base_model.layers[:-30]:
        layer.trainable = False

    # Recompile with lower learning rate
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-4),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    # New callbacks for fine-tuning
    early_stop_ft = EarlyStopping(
        monitor='val_accuracy',
        patience=10,
        restore_best_weights=True,
        verbose=1
    )

    reduce_lr_ft = ReduceLROnPlateau(
        monitor='val_accuracy',
        factor=0.5,
        patience=5,
        min_lr=1e-8,
        verbose=1
    )

    # Fit phase 2
    train_generator = train_datagen.flow(X_train, y_train, batch_size=BATCH_SIZE, seed=SEED)
    val_generator = val_datagen.flow(X_val, y_val, batch_size=BATCH_SIZE, shuffle=False)

    model.fit(
        train_generator,
        steps_per_epoch=steps_per_epoch,
        epochs=EPOCHS,
        validation_data=val_generator,
        validation_steps=validation_steps,
        callbacks=[early_stop_ft, reduce_lr_ft],
        verbose=1
    )

    # ==================== Evaluation ====================
    print("\nEvaluating on validation set...")

    # Preprocess validation data
    X_val_processed = tf.keras.applications.efficientnet.preprocess_input(X_val.copy())

    # Predict
    y_pred_proba = model.predict(X_val_processed, verbose=0)
    y_pred = (y_pred_proba > 0.5).astype(int).flatten()

    # Calculate accuracy
    fold_accuracy = accuracy_score(y_val, y_pred)

    print(f"\n>>> Fold {fold_num} Accuracy: {fold_accuracy:.4f} <<<")

    # Cleanup
    del model, base_model
    keras.backend.clear_session()

    return y_pred, y_val, fold_accuracy

# %%
def run_10fold_cross_validation(X, y):
    """
    Run 10-fold stratified cross-validation.

    Note: StratifiedKFold ensures each fold has similar class distribution.
    This is important for imbalanced datasets.
    """
    print("\n" + "="*60)
    print("STARTING 10-FOLD STRATIFIED CROSS-VALIDATION")
    print("="*60)

    skf = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=SEED)

    fold_accuracies = []
    all_y_true = []
    all_y_pred = []

    for fold_idx, (train_idx, val_idx) in enumerate(skf.split(X, y), start=1):
        # Split data for this fold
        X_train, X_val = X[train_idx], X[val_idx]
        y_train, y_val = y[train_idx], y[val_idx]

        # Train and evaluate
        y_pred, y_true, accuracy = train_fold(X_train, y_train, X_val, y_val, fold_idx)

        # Store results
        fold_accuracies.append(accuracy)
        all_y_true.extend(y_true)
        all_y_pred.extend(y_pred)

    return fold_accuracies, np.array(all_y_true), np.array(all_y_pred)

# %%
def print_final_results(fold_accuracies, y_true, y_pred):
    """Print comprehensive final results."""

    print("\n" + "="*60)
    print("FINAL RESULTS - 10-FOLD CROSS-VALIDATION")
    print("="*60)

    # Individual fold results
    print("\nAccuracy per fold:")
    for i, acc in enumerate(fold_accuracies, 1):
        status = "✓" if acc >= 0.95 else "○" if acc >= 0.85 else "✗"
        print(f"  Fold {i:2d}: {acc:.4f} {status}")

    # Summary statistics
    mean_acc = np.mean(fold_accuracies)
    std_acc = np.std(fold_accuracies)
    min_acc = np.min(fold_accuracies)
    max_acc = np.max(fold_accuracies)

    print(f"\n{'─'*40}")
    print(f"Mean Accuracy:  {mean_acc:.4f}")
    print(f"Std Deviation:  {std_acc:.4f}")
    print(f"Min Accuracy:   {min_acc:.4f}")
    print(f"Max Accuracy:   {max_acc:.4f}")
    print(f"{'─'*40}")

    # Classification report
    print("\nOverall Classification Report:")
    print(classification_report(y_true, y_pred, target_names=['Normal', 'Fracture'], digits=4))

    # Confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    print("Confusion Matrix:")
    print(f"                  Predicted")
    print(f"                Normal  Fracture")
    print(f"Actual Normal     {cm[0,0]:4d}     {cm[0,1]:4d}")
    print(f"       Fracture   {cm[1,0]:4d}     {cm[1,1]:4d}")

    # Grading
    print("\n" + "="*60)
    print("GRADE CALCULATION")
    print("="*60)
    print(f"\n10-Fold CV Mean Accuracy: {mean_acc:.4f}")

    if mean_acc >= 0.95:
        grade = 15
        status = "FULL GRADE"
    elif mean_acc >= 0.85:
        grade = 10
        status = "PARTIAL GRADE"
    else:
        grade = 5
        status = "MINIMUM GRADE"

    print(f"Grade: {grade}/15 points ({status})")

    if mean_acc >= 0.95:
        print("✓ Accuracy >= 0.95: Requirement met!")
    elif mean_acc >= 0.85:
        print("○ Accuracy >= 0.85 but < 0.95")
    else:
        print("✗ Accuracy < 0.85")

    return mean_acc

# %%
def main():
    """Main execution function."""

    print("="*60)
    print("BONE FRACTURE CLASSIFICATION SYSTEM")
    print("Transfer Learning with EfficientNetB0")
    print("="*60)

    # Check GPU
    print("\n[1/4] Checking hardware...")
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        print(f"✓ GPU available: {gpus[0]}")
        try:
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
        except RuntimeError as e:
            print(f"  GPU config warning: {e}")
    else:
        print("✗ No GPU found - using CPU (will be slower)")

    # Verify directories
    print("\n[2/4] Verifying data directories...")
    print(f"  Looking for: {DATA_DIR}/")
    print(f"               ├── fracture/")
    print(f"               └── normal/")

    if not os.path.exists(DATA_DIR):
        raise FileNotFoundError(
            f"\nERROR: '{DATA_DIR}' folder not found!\n"
            f"Make sure 'data' folder is at the same level as 'sample_data'"
        )
    if not os.path.exists(FRACTURE_DIR):
        raise FileNotFoundError(f"\nERROR: '{FRACTURE_DIR}' folder not found!")
    if not os.path.exists(NORMAL_DIR):
        raise FileNotFoundError(f"\nERROR: '{NORMAL_DIR}' folder not found!")

    print("✓ All directories found")

    # Load data
    print("\n[3/4] Loading dataset...")
    X, y = load_dataset()

    # Run cross-validation
    print("\n[4/4] Running 10-fold cross-validation...")
    fold_accuracies, y_true, y_pred = run_10fold_cross_validation(X, y)

    # Print results
    mean_accuracy = print_final_results(fold_accuracies, y_true, y_pred)

    print("\n" + "="*60)
    print("EXECUTION COMPLETED")
    print("="*60)

    return mean_accuracy

# %%
# Entry point
if __name__ == "__main__":
    final_accuracy = main()
# Out:
# ============================================================
# BONE FRACTURE CLASSIFICATION SYSTEM
# Transfer Learning with EfficientNetB0
# ============================================================
#
# [1/4] Checking hardware...
# ✗ No GPU found - using CPU (will be slower)
#
# [2/4] Verifying data directories...
#   Looking for: data/
#                ├── fracture/
#                └── normal/
# ✓ All directories found
#
# [3/4] Loading dataset...
# Loading fracture images...
#   Loaded 111 fracture images
# Loading normal images...
#   Loaded 82 normal images
#
# Dataset Summary:
#   Total images: 193
#   Fracture: 111, Normal: 82
#   Image shape: (224, 224, 3)
#
# [4/4] Running 10-fold cross-validation...
#
# ============================================================
# STARTING 10-FOLD STRATIFIED CROSS-VALIDATION
# ============================================================
#
# ============================================================
# FOLD 1/10
# ============================================================
# Train: 173 samples | Val: 20 samples
# Train distribution - Fracture: 99, Normal: 74
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# [Phase 1] Training classification head (base frozen)...
# Epoch 1/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 32s 872ms/step - accuracy: 0.6579 - loss: 0.7465 - val_accuracy: 0.8750 - val_loss: 0.3767 - learning_rate: 0.0010
# Epoch 2/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.7500 - loss: 0.5353 - val_accuracy: 0.8750 - val_loss: 0.3692 - learning_rate: 0.0010
# Epoch 3/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 623ms/step - accuracy: 0.8883 - loss: 0.3062 - val_accuracy: 1.0000 - val_loss: 0.2854 - learning_rate: 0.0010
# Epoch 4/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - accuracy: 1.0000 - loss: 0.0337 - val_accuracy: 1.0000 - val_loss: 0.2847 - learning_rate: 0.0010
# Epoch 5/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 712ms/step - accuracy: 0.9402 - loss: 0.2651 - val_accuracy: 1.0000 - val_loss: 0.2457 - learning_rate: 0.0010
# Epoch 6/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0753 - val_accuracy: 1.0000 - val_loss: 0.2448 - learning_rate: 0.0010
# Epoch 7/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 582ms/step - accuracy: 0.9442 - loss: 0.1700
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 625ms/step - accuracy: 0.9417 - loss: 0.1726 - val_accuracy: 1.0000 - val_loss: 0.2050 - learning_rate: 0.0010
# Epoch 8/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 0.0665 - val_accuracy: 1.0000 - val_loss: 0.2036 - learning_rate: 5.0000e-04
# Epoch 9/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8817 - loss: 0.2054 - val_accuracy: 1.0000 - val_loss: 0.1514 - learning_rate: 5.0000e-04
# Epoch 10/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.6000 - loss: 0.6636 - val_accuracy: 1.0000 - val_loss: 0.1496 - learning_rate: 5.0000e-04
# Epoch 11/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.9208 - loss: 0.2085
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 978ms/step - accuracy: 0.9208 - loss: 0.2090 - val_accuracy: 1.0000 - val_loss: 0.1274 - learning_rate: 5.0000e-04
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 3.
#
# [Phase 2] Fine-tuning top layers of base model...
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 37s 857ms/step - accuracy: 0.9296 - loss: 0.2241 - val_accuracy: 0.9375 - val_loss: 0.3060 - learning_rate: 1.0000e-04
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.6250 - loss: 0.7713 - val_accuracy: 0.9375 - val_loss: 0.3043 - learning_rate: 1.0000e-04
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 963ms/step - accuracy: 0.8778 - loss: 0.2774 - val_accuracy: 0.9375 - val_loss: 0.2623 - learning_rate: 1.0000e-04
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 0.7500 - loss: 0.2450 - val_accuracy: 0.9375 - val_loss: 0.2619 - learning_rate: 1.0000e-04
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 15s 697ms/step - accuracy: 0.8536 - loss: 0.3051 - val_accuracy: 0.9375 - val_loss: 0.2364 - learning_rate: 1.0000e-04
# Epoch 6/50
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 11s 554ms/step - accuracy: 0.8750 - loss: 0.2722
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - accuracy: 0.8750 - loss: 0.2722 - val_accuracy: 0.9375 - val_loss: 0.2350 - learning_rate: 1.0000e-04
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 15s 718ms/step - accuracy: 0.9102 - loss: 0.2276 - val_accuracy: 0.9375 - val_loss: 0.2153 - learning_rate: 5.0000e-05
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.7500 - loss: 0.5140 - val_accuracy: 0.9375 - val_loss: 0.2153 - learning_rate: 5.0000e-05
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 18s 714ms/step - accuracy: 0.8779 - loss: 0.4025 - val_accuracy: 0.9375 - val_loss: 0.1961 - learning_rate: 5.0000e-05
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 1.0000 - loss: 0.0578 - val_accuracy: 0.9375 - val_loss: 0.1952 - learning_rate: 5.0000e-05
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 671ms/step - accuracy: 0.8844 - loss: 0.2398
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 18s 717ms/step - accuracy: 0.8864 - loss: 0.2365 - val_accuracy: 0.9375 - val_loss: 0.1774 - learning_rate: 5.0000e-05
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
#
# Evaluating on validation set...
#
# >>> Fold 1 Accuracy: 0.9500 <<<
#
# ============================================================
# FOLD 2/10
# ============================================================
# Train: 173 samples | Val: 20 samples
# Train distribution - Fracture: 100, Normal: 73
#
# [Phase 1] Training classification head (base frozen)...
# Epoch 1/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 29s 765ms/step - accuracy: 0.4894 - loss: 1.2785 - val_accuracy: 0.6875 - val_loss: 0.5552 - learning_rate: 0.0010
# Epoch 2/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - accuracy: 0.4000 - loss: 1.6483 - val_accuracy: 0.6875 - val_loss: 0.5421 - learning_rate: 0.0010
# Epoch 3/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8127 - loss: 0.4816 - val_accuracy: 0.8750 - val_loss: 0.4032 - learning_rate: 0.0010
# Epoch 4/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0952 - val_accuracy: 0.8750 - val_loss: 0.4015 - learning_rate: 0.0010
# Epoch 5/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.8673 - loss: 0.2843 - val_accuracy: 0.8750 - val_loss: 0.3636 - learning_rate: 0.0010
# Epoch 6/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - accuracy: 0.8750 - loss: 0.2049 - val_accuracy: 0.8750 - val_loss: 0.3595 - learning_rate: 0.0010
# Epoch 7/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.9444 - loss: 0.1353
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 972ms/step - accuracy: 0.9439 - loss: 0.1358 - val_accuracy: 0.8750 - val_loss: 0.3614 - learning_rate: 0.0010
# Epoch 8/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 1.0000 - loss: 0.1643 - val_accuracy: 0.8750 - val_loss: 0.3641 - learning_rate: 5.0000e-04
# Epoch 9/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 547ms/step - accuracy: 0.9370 - loss: 0.2493 - val_accuracy: 0.8125 - val_loss: 0.3608 - learning_rate: 5.0000e-04
# Epoch 10/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.7500 - loss: 0.7717 - val_accuracy: 0.8125 - val_loss: 0.3584 - learning_rate: 5.0000e-04
# Epoch 11/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.9315 - loss: 0.1462
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 614ms/step - accuracy: 0.9307 - loss: 0.1475 - val_accuracy: 0.8125 - val_loss: 0.3602 - learning_rate: 5.0000e-04
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 3.
#
# [Phase 2] Fine-tuning top layers of base model...
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 36s 880ms/step - accuracy: 0.7719 - loss: 0.5056 - val_accuracy: 0.9375 - val_loss: 0.3533 - learning_rate: 1.0000e-04
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - accuracy: 0.7500 - loss: 0.5071 - val_accuracy: 0.9375 - val_loss: 0.3490 - learning_rate: 1.0000e-04
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8861 - loss: 0.2872 - val_accuracy: 0.9375 - val_loss: 0.3213 - learning_rate: 1.0000e-04
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.8750 - loss: 0.4072 - val_accuracy: 0.9375 - val_loss: 0.3190 - learning_rate: 1.0000e-04
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 990ms/step - accuracy: 0.9039 - loss: 0.2747 - val_accuracy: 0.9375 - val_loss: 0.2776 - learning_rate: 1.0000e-04
# Epoch 6/50
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 7s 352ms/step - accuracy: 0.8000 - loss: 0.2618
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.8000 - loss: 0.2618 - val_accuracy: 0.9375 - val_loss: 0.2783 - learning_rate: 1.0000e-04
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 15s 699ms/step - accuracy: 0.9498 - loss: 0.1619 - val_accuracy: 0.9375 - val_loss: 0.2670 - learning_rate: 5.0000e-05
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8750 - loss: 0.4046 - val_accuracy: 0.9375 - val_loss: 0.2660 - learning_rate: 5.0000e-05
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 17s 699ms/step - accuracy: 0.9116 - loss: 0.2118 - val_accuracy: 0.9375 - val_loss: 0.2539 - learning_rate: 5.0000e-05
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.7500 - loss: 0.5514 - val_accuracy: 0.9375 - val_loss: 0.2547 - learning_rate: 5.0000e-05
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 647ms/step - accuracy: 0.9102 - loss: 0.1802
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 15s 720ms/step - accuracy: 0.9109 - loss: 0.1795 - val_accuracy: 0.9375 - val_loss: 0.2713 - learning_rate: 5.0000e-05
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
#
# Evaluating on validation set...
#
# >>> Fold 2 Accuracy: 0.9500 <<<
#
# ============================================================
# FOLD 3/10
# ============================================================
# Train: 173 samples | Val: 20 samples
# Train distribution - Fracture: 100, Normal: 73
#
# [Phase 1] Training classification head (base frozen)...
# Epoch 1/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 29s 766ms/step - accuracy: 0.5023 - loss: 0.9917 - val_accuracy: 0.8125 - val_loss: 0.4198 - learning_rate: 0.0010
# Epoch 2/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.6250 - loss: 0.9302 - val_accuracy: 0.8750 - val_loss: 0.4111 - learning_rate: 0.0010
# Epoch 3/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 602ms/step - accuracy: 0.8867 - loss: 0.2937 - val_accuracy: 1.0000 - val_loss: 0.2316 - learning_rate: 0.0010
# Epoch 4/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0588 - val_accuracy: 1.0000 - val_loss: 0.2273 - learning_rate: 0.0010
# Epoch 5/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 679ms/step - accuracy: 0.8418 - loss: 0.2908 - val_accuracy: 0.9375 - val_loss: 0.1984 - learning_rate: 0.0010
# Epoch 6/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.8750 - loss: 0.1838 - val_accuracy: 0.9375 - val_loss: 0.2016 - learning_rate: 0.0010
# Epoch 7/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 560ms/step - accuracy: 0.8868 - loss: 0.2303
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 797ms/step - accuracy: 0.8870 - loss: 0.2295 - val_accuracy: 0.9375 - val_loss: 0.2034 - learning_rate: 0.0010
# Epoch 8/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0699 - val_accuracy: 0.9375 - val_loss: 0.2031 - learning_rate: 5.0000e-04
# Epoch 9/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 598ms/step - accuracy: 0.9541 - loss: 0.1244 - val_accuracy: 0.9375 - val_loss: 0.1791 - learning_rate: 5.0000e-04
# Epoch 10/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0694 - val_accuracy: 0.9375 - val_loss: 0.1796 - learning_rate: 5.0000e-04
# Epoch 11/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 554ms/step - accuracy: 0.9325 - loss: 0.1842
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 19s 596ms/step - accuracy: 0.9325 - loss: 0.1846 - val_accuracy: 0.9375 - val_loss: 0.1747 - learning_rate: 5.0000e-04
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 3.
#
# [Phase 2] Fine-tuning top layers of base model...
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 37s 870ms/step - accuracy: 0.8139 - loss: 0.5158 - val_accuracy: 1.0000 - val_loss: 0.2072 - learning_rate: 1.0000e-04
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 0.8750 - loss: 0.3422 - val_accuracy: 1.0000 - val_loss: 0.2083 - learning_rate: 1.0000e-04
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 35s 697ms/step - accuracy: 0.9041 - loss: 0.2200 - val_accuracy: 1.0000 - val_loss: 0.2005 - learning_rate: 1.0000e-04
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.7500 - loss: 0.3500 - val_accuracy: 1.0000 - val_loss: 0.1988 - learning_rate: 1.0000e-04
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 986ms/step - accuracy: 0.8553 - loss: 0.3595 - val_accuracy: 1.0000 - val_loss: 0.1574 - learning_rate: 1.0000e-04
# Epoch 6/50
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 10s 532ms/step - accuracy: 1.0000 - loss: 0.1002
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 1.0000 - loss: 0.1002 - val_accuracy: 1.0000 - val_loss: 0.1553 - learning_rate: 1.0000e-04
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9372 - loss: 0.1815 - val_accuracy: 1.0000 - val_loss: 0.1320 - learning_rate: 5.0000e-05
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.8750 - loss: 0.5063 - val_accuracy: 1.0000 - val_loss: 0.1321 - learning_rate: 5.0000e-05
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 986ms/step - accuracy: 0.9155 - loss: 0.2158 - val_accuracy: 1.0000 - val_loss: 0.1213 - learning_rate: 5.0000e-05
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - accuracy: 0.8750 - loss: 0.2748 - val_accuracy: 1.0000 - val_loss: 0.1205 - learning_rate: 5.0000e-05
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - accuracy: 0.9707 - loss: 0.1278
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 32s 677ms/step - accuracy: 0.9695 - loss: 0.1298 - val_accuracy: 1.0000 - val_loss: 0.1048 - learning_rate: 5.0000e-05
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
#
# Evaluating on validation set...
#
# >>> Fold 3 Accuracy: 1.0000 <<<
#
# ============================================================
# FOLD 4/10
# ============================================================
# Train: 174 samples | Val: 19 samples
# Train distribution - Fracture: 100, Normal: 74
#
# [Phase 1] Training classification head (base frozen)...
# Epoch 1/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 28s 743ms/step - accuracy: 0.5968 - loss: 0.7983 - val_accuracy: 0.6875 - val_loss: 0.5257 - learning_rate: 0.0010
# Epoch 2/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8750 - loss: 0.4490 - val_accuracy: 0.7500 - val_loss: 0.5147 - learning_rate: 0.0010
# Epoch 3/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 16s 576ms/step - accuracy: 0.8944 - loss: 0.2835 - val_accuracy: 0.7500 - val_loss: 0.4262 - learning_rate: 0.0010
# Epoch 4/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 1.0000 - loss: 0.1828 - val_accuracy: 0.7500 - val_loss: 0.4241 - learning_rate: 0.0010
# Epoch 5/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 998ms/step - accuracy: 0.9259 - loss: 0.2031 - val_accuracy: 0.9375 - val_loss: 0.2708 - learning_rate: 0.0010
# Epoch 6/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - accuracy: 0.8750 - loss: 0.3632 - val_accuracy: 0.9375 - val_loss: 0.2670 - learning_rate: 0.0010
# Epoch 7/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 30s 590ms/step - accuracy: 0.9233 - loss: 0.1768 - val_accuracy: 1.0000 - val_loss: 0.1558 - learning_rate: 0.0010
# Epoch 8/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - accuracy: 0.8750 - loss: 0.1914 - val_accuracy: 1.0000 - val_loss: 0.1507 - learning_rate: 0.0010
# Epoch 9/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 584ms/step - accuracy: 0.9646 - loss: 0.1199 - val_accuracy: 1.0000 - val_loss: 0.1140 - learning_rate: 0.0010
# Epoch 10/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 0.1039 - val_accuracy: 1.0000 - val_loss: 0.1139 - learning_rate: 0.0010
# Epoch 11/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - accuracy: 0.9081 - loss: 0.1526
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 995ms/step - accuracy: 0.9090 - loss: 0.1532 - val_accuracy: 1.0000 - val_loss: 0.0911 - learning_rate: 0.0010
# Epoch 12/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0359 - val_accuracy: 1.0000 - val_loss: 0.0905 - learning_rate: 5.0000e-04
# Epoch 13/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 32s 590ms/step - accuracy: 0.9205 - loss: 0.1719 - val_accuracy: 1.0000 - val_loss: 0.0732 - learning_rate: 5.0000e-04
# Epoch 14/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.6250 - loss: 0.5762 - val_accuracy: 1.0000 - val_loss: 0.0730 - learning_rate: 5.0000e-04
# Epoch 15/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - accuracy: 0.9619 - loss: 0.1261
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 581ms/step - accuracy: 0.9620 - loss: 0.1262 - val_accuracy: 1.0000 - val_loss: 0.0699 - learning_rate: 5.0000e-04
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 7.
#
# [Phase 2] Fine-tuning top layers of base model...
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 36s 890ms/step - accuracy: 0.8662 - loss: 0.3847 - val_accuracy: 1.0000 - val_loss: 0.1651 - learning_rate: 1.0000e-04
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0754 - val_accuracy: 1.0000 - val_loss: 0.1661 - learning_rate: 1.0000e-04
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9284 - loss: 0.2130 - val_accuracy: 0.9375 - val_loss: 0.1835 - learning_rate: 1.0000e-04
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 1.0000 - loss: 0.0459 - val_accuracy: 0.9375 - val_loss: 0.1847 - learning_rate: 1.0000e-04
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 985ms/step - accuracy: 0.9592 - loss: 0.1498 - val_accuracy: 1.0000 - val_loss: 0.1565 - learning_rate: 1.0000e-04
# Epoch 6/50
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 10s 546ms/step - accuracy: 1.0000 - loss: 0.0299
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - accuracy: 1.0000 - loss: 0.0299 - val_accuracy: 1.0000 - val_loss: 0.1545 - learning_rate: 1.0000e-04
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 15s 708ms/step - accuracy: 0.8684 - loss: 0.2162 - val_accuracy: 1.0000 - val_loss: 0.1292 - learning_rate: 5.0000e-05
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0264 - val_accuracy: 1.0000 - val_loss: 0.1282 - learning_rate: 5.0000e-05
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 15s 706ms/step - accuracy: 0.9352 - loss: 0.1499 - val_accuracy: 1.0000 - val_loss: 0.1214 - learning_rate: 5.0000e-05
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0138 - val_accuracy: 1.0000 - val_loss: 0.1207 - learning_rate: 5.0000e-05
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 666ms/step - accuracy: 0.9325 - loss: 0.1652
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 988ms/step - accuracy: 0.9324 - loss: 0.1667 - val_accuracy: 1.0000 - val_loss: 0.1079 - learning_rate: 5.0000e-05
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
#
# Evaluating on validation set...
#
# >>> Fold 4 Accuracy: 1.0000 <<<
#
# ============================================================
# FOLD 5/10
# ============================================================
# Train: 174 samples | Val: 19 samples
# Train distribution - Fracture: 100, Normal: 74
#
# [Phase 1] Training classification head (base frozen)...
# Epoch 1/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 29s 748ms/step - accuracy: 0.5521 - loss: 0.7928 - val_accuracy: 0.7500 - val_loss: 0.4254 - learning_rate: 0.0010
# Epoch 2/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 1.0000 - loss: 0.2038 - val_accuracy: 0.8125 - val_loss: 0.4154 - learning_rate: 0.0010
# Epoch 3/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 15s 589ms/step - accuracy: 0.8090 - loss: 0.3518 - val_accuracy: 1.0000 - val_loss: 0.2608 - learning_rate: 0.0010
# Epoch 4/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.8750 - loss: 0.2250 - val_accuracy: 1.0000 - val_loss: 0.2576 - learning_rate: 0.0010
# Epoch 5/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 550ms/step - accuracy: 0.9043 - loss: 0.2056 - val_accuracy: 1.0000 - val_loss: 0.2005 - learning_rate: 0.0010
# Epoch 6/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.8750 - loss: 0.5306 - val_accuracy: 1.0000 - val_loss: 0.1999 - learning_rate: 0.0010
# Epoch 7/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 549ms/step - accuracy: 0.9380 - loss: 0.1769
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 659ms/step - accuracy: 0.9373 - loss: 0.1781 - val_accuracy: 0.9375 - val_loss: 0.1708 - learning_rate: 0.0010
# Epoch 8/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9375 - val_loss: 0.1695 - learning_rate: 5.0000e-04
# Epoch 9/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 587ms/step - accuracy: 0.9259 - loss: 0.2259 - val_accuracy: 0.9375 - val_loss: 0.1518 - learning_rate: 5.0000e-04
# Epoch 10/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0855 - val_accuracy: 0.9375 - val_loss: 0.1514 - learning_rate: 5.0000e-04
# Epoch 11/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 549ms/step - accuracy: 0.8902 - loss: 0.2349
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 995ms/step - accuracy: 0.8913 - loss: 0.2338 - val_accuracy: 0.9375 - val_loss: 0.1192 - learning_rate: 5.0000e-04
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 3.
#
# [Phase 2] Fine-tuning top layers of base model...
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 36s 848ms/step - accuracy: 0.8414 - loss: 0.3391 - val_accuracy: 1.0000 - val_loss: 0.2442 - learning_rate: 1.0000e-04
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8750 - loss: 0.2473 - val_accuracy: 1.0000 - val_loss: 0.2438 - learning_rate: 1.0000e-04
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 988ms/step - accuracy: 0.8745 - loss: 0.3271 - val_accuracy: 1.0000 - val_loss: 0.2097 - learning_rate: 1.0000e-04
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 1.0000 - loss: 0.0169 - val_accuracy: 1.0000 - val_loss: 0.2083 - learning_rate: 1.0000e-04
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8890 - loss: 0.2771 - val_accuracy: 1.0000 - val_loss: 0.1844 - learning_rate: 1.0000e-04
# Epoch 6/50
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 10s 520ms/step - accuracy: 1.0000 - loss: 0.0783
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 1.0000 - loss: 0.0783 - val_accuracy: 1.0000 - val_loss: 0.1828 - learning_rate: 1.0000e-04
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 15s 704ms/step - accuracy: 0.9040 - loss: 0.2006 - val_accuracy: 1.0000 - val_loss: 0.1602 - learning_rate: 5.0000e-05
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 1.0000 - loss: 0.0983 - val_accuracy: 1.0000 - val_loss: 0.1587 - learning_rate: 5.0000e-05
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 15s 695ms/step - accuracy: 0.8811 - loss: 0.3110 - val_accuracy: 1.0000 - val_loss: 0.1417 - learning_rate: 5.0000e-05
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8750 - loss: 0.1622 - val_accuracy: 1.0000 - val_loss: 0.1407 - learning_rate: 5.0000e-05
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 662ms/step - accuracy: 0.9316 - loss: 0.2008
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 965ms/step - accuracy: 0.9312 - loss: 0.2009 - val_accuracy: 1.0000 - val_loss: 0.1297 - learning_rate: 5.0000e-05
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
#
# Evaluating on validation set...
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7cdd812f3240> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# >>> Fold 5 Accuracy: 1.0000 <<<
#
# ============================================================
# FOLD 6/10
# ============================================================
# Train: 174 samples | Val: 19 samples
# Train distribution - Fracture: 100, Normal: 74
#
# [Phase 1] Training classification head (base frozen)...
# Epoch 1/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 29s 754ms/step - accuracy: 0.6692 - loss: 0.6052 - val_accuracy: 0.8750 - val_loss: 0.4790 - learning_rate: 0.0010
# Epoch 2/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8750 - loss: 0.2058 - val_accuracy: 0.8750 - val_loss: 0.4705 - learning_rate: 0.0010
# Epoch 3/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 16s 556ms/step - accuracy: 0.8890 - loss: 0.2086 - val_accuracy: 0.9375 - val_loss: 0.3369 - learning_rate: 0.0010
# Epoch 4/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - accuracy: 1.0000 - loss: 0.1337 - val_accuracy: 0.9375 - val_loss: 0.3319 - learning_rate: 0.0010
# Epoch 5/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 991ms/step - accuracy: 0.8900 - loss: 0.2060 - val_accuracy: 0.8750 - val_loss: 0.2820 - learning_rate: 0.0010
# Epoch 6/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 0.1819 - val_accuracy: 0.8750 - val_loss: 0.2803 - learning_rate: 0.0010
# Epoch 7/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - accuracy: 0.9237 - loss: 0.1423
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 32s 587ms/step - accuracy: 0.9234 - loss: 0.1423 - val_accuracy: 0.8750 - val_loss: 0.2371 - learning_rate: 0.0010
# Epoch 8/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.8750 - loss: 0.4425 - val_accuracy: 0.8750 - val_loss: 0.2368 - learning_rate: 5.0000e-04
# Epoch 9/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 585ms/step - accuracy: 0.9262 - loss: 0.1308 - val_accuracy: 0.8750 - val_loss: 0.2245 - learning_rate: 5.0000e-04
# Epoch 10/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 0.0447 - val_accuracy: 0.8750 - val_loss: 0.2225 - learning_rate: 5.0000e-04
# Epoch 11/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - accuracy: 0.9319 - loss: 0.1342
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 588ms/step - accuracy: 0.9325 - loss: 0.1331 - val_accuracy: 0.8750 - val_loss: 0.2080 - learning_rate: 5.0000e-04
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 3.
#
# [Phase 2] Fine-tuning top layers of base model...
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 36s 858ms/step - accuracy: 0.8362 - loss: 0.3688 - val_accuracy: 0.9375 - val_loss: 0.3479 - learning_rate: 1.0000e-04
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.7500 - loss: 0.5576 - val_accuracy: 0.9375 - val_loss: 0.3473 - learning_rate: 1.0000e-04
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 992ms/step - accuracy: 0.8953 - loss: 0.2240 - val_accuracy: 1.0000 - val_loss: 0.3320 - learning_rate: 1.0000e-04
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 0.8750 - loss: 0.3886 - val_accuracy: 1.0000 - val_loss: 0.3314 - learning_rate: 1.0000e-04
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9088 - loss: 0.2374 - val_accuracy: 1.0000 - val_loss: 0.3043 - learning_rate: 1.0000e-04
# Epoch 6/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 1.0000 - loss: 0.1130 - val_accuracy: 1.0000 - val_loss: 0.3022 - learning_rate: 1.0000e-04
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9131 - loss: 0.2147 - val_accuracy: 1.0000 - val_loss: 0.2618 - learning_rate: 1.0000e-04
# Epoch 8/50
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 16s 849ms/step - accuracy: 1.0000 - loss: 0.0613
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 1.0000 - loss: 0.0613 - val_accuracy: 1.0000 - val_loss: 0.2592 - learning_rate: 1.0000e-04
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 685ms/step - accuracy: 0.8754 - loss: 0.2472 - val_accuracy: 1.0000 - val_loss: 0.2350 - learning_rate: 5.0000e-05
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0629 - val_accuracy: 1.0000 - val_loss: 0.2337 - learning_rate: 5.0000e-05
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 708ms/step - accuracy: 0.9261 - loss: 0.1958 - val_accuracy: 0.9375 - val_loss: 0.2193 - learning_rate: 5.0000e-05
# Epoch 12/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.8750 - loss: 0.3795 - val_accuracy: 0.9375 - val_loss: 0.2193 - learning_rate: 5.0000e-05
# Epoch 13/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 640ms/step - accuracy: 0.9245 - loss: 0.1571
# Epoch 13: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 18s 682ms/step - accuracy: 0.9244 - loss: 0.1579 - val_accuracy: 0.9375 - val_loss: 0.2101 - learning_rate: 5.0000e-05
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 3.
#
# Evaluating on validation set...
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7cdd77bd6c00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# >>> Fold 6 Accuracy: 1.0000 <<<
#
# ============================================================
# FOLD 7/10
# ============================================================
# Train: 174 samples | Val: 19 samples
# Train distribution - Fracture: 100, Normal: 74
#
# [Phase 1] Training classification head (base frozen)...
# Epoch 1/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 784ms/step - accuracy: 0.5590 - loss: 0.9389 - val_accuracy: 0.9375 - val_loss: 0.4738 - learning_rate: 0.0010
# Epoch 2/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.8750 - loss: 0.2131 - val_accuracy: 0.9375 - val_loss: 0.4620 - learning_rate: 0.0010
# Epoch 3/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 607ms/step - accuracy: 0.8281 - loss: 0.3792 - val_accuracy: 1.0000 - val_loss: 0.2811 - learning_rate: 0.0010
# Epoch 4/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8750 - loss: 0.6260 - val_accuracy: 1.0000 - val_loss: 0.2782 - learning_rate: 0.0010
# Epoch 5/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8983 - loss: 0.2229 - val_accuracy: 0.9375 - val_loss: 0.2600 - learning_rate: 0.0010
# Epoch 6/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.6250 - loss: 0.3949 - val_accuracy: 0.9375 - val_loss: 0.2611 - learning_rate: 0.0010
# Epoch 7/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.9646 - loss: 0.0873
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 968ms/step - accuracy: 0.9629 - loss: 0.0897 - val_accuracy: 0.8750 - val_loss: 0.2370 - learning_rate: 0.0010
# Epoch 8/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8750 - loss: 0.2965 - val_accuracy: 0.8750 - val_loss: 0.2373 - learning_rate: 5.0000e-04
# Epoch 9/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 992ms/step - accuracy: 0.9573 - loss: 0.1291 - val_accuracy: 0.8750 - val_loss: 0.2117 - learning_rate: 5.0000e-04
# Epoch 10/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.1029 - val_accuracy: 0.8750 - val_loss: 0.2102 - learning_rate: 5.0000e-04
# Epoch 11/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 562ms/step - accuracy: 0.9307 - loss: 0.1569
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 605ms/step - accuracy: 0.9298 - loss: 0.1592 - val_accuracy: 0.9375 - val_loss: 0.1815 - learning_rate: 5.0000e-04
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 3.
#
# [Phase 2] Fine-tuning top layers of base model...
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 38s 885ms/step - accuracy: 0.8556 - loss: 0.3404 - val_accuracy: 1.0000 - val_loss: 0.2535 - learning_rate: 1.0000e-04
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.5000 - loss: 0.9127 - val_accuracy: 1.0000 - val_loss: 0.2522 - learning_rate: 1.0000e-04
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 15s 704ms/step - accuracy: 0.8815 - loss: 0.2583 - val_accuracy: 1.0000 - val_loss: 0.2341 - learning_rate: 1.0000e-04
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.8750 - loss: 0.1109 - val_accuracy: 1.0000 - val_loss: 0.2325 - learning_rate: 1.0000e-04
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 18s 702ms/step - accuracy: 0.9113 - loss: 0.1995 - val_accuracy: 1.0000 - val_loss: 0.2111 - learning_rate: 1.0000e-04
# Epoch 6/50
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 11s 563ms/step - accuracy: 1.0000 - loss: 0.0689
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0689 - val_accuracy: 1.0000 - val_loss: 0.2102 - learning_rate: 1.0000e-04
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 19s 708ms/step - accuracy: 0.9754 - loss: 0.1081 - val_accuracy: 1.0000 - val_loss: 0.1874 - learning_rate: 5.0000e-05
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8750 - loss: 0.2152 - val_accuracy: 1.0000 - val_loss: 0.1856 - learning_rate: 5.0000e-05
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 17s 693ms/step - accuracy: 0.9508 - loss: 0.1623 - val_accuracy: 1.0000 - val_loss: 0.1632 - learning_rate: 5.0000e-05
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.8750 - loss: 0.4941 - val_accuracy: 1.0000 - val_loss: 0.1623 - learning_rate: 5.0000e-05
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 656ms/step - accuracy: 0.9218 - loss: 0.1767
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 763ms/step - accuracy: 0.9215 - loss: 0.1771 - val_accuracy: 1.0000 - val_loss: 0.1433 - learning_rate: 5.0000e-05
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
#
# Evaluating on validation set...
#
# >>> Fold 7 Accuracy: 1.0000 <<<
#
# ============================================================
# FOLD 8/10
# ============================================================
# Train: 174 samples | Val: 19 samples
# Train distribution - Fracture: 100, Normal: 74
#
# [Phase 1] Training classification head (base frozen)...
# Epoch 1/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 29s 759ms/step - accuracy: 0.6006 - loss: 0.7373 - val_accuracy: 0.9375 - val_loss: 0.2941 - learning_rate: 0.0010
# Epoch 2/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.7500 - loss: 0.3789 - val_accuracy: 0.9375 - val_loss: 0.2799 - learning_rate: 0.0010
# Epoch 3/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 585ms/step - accuracy: 0.8661 - loss: 0.2744 - val_accuracy: 1.0000 - val_loss: 0.1959 - learning_rate: 0.0010
# Epoch 4/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 1.0000 - loss: 0.1036 - val_accuracy: 1.0000 - val_loss: 0.1946 - learning_rate: 0.0010
# Epoch 5/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 997ms/step - accuracy: 0.9087 - loss: 0.2054 - val_accuracy: 0.9375 - val_loss: 0.1898 - learning_rate: 0.0010
# Epoch 6/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 1.0000 - loss: 0.0509 - val_accuracy: 0.9375 - val_loss: 0.1891 - learning_rate: 0.0010
# Epoch 7/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 552ms/step - accuracy: 0.9287 - loss: 0.2333
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.9290 - loss: 0.2319 - val_accuracy: 1.0000 - val_loss: 0.1163 - learning_rate: 0.0010
# Epoch 8/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0901 - val_accuracy: 1.0000 - val_loss: 0.1153 - learning_rate: 5.0000e-04
# Epoch 9/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 994ms/step - accuracy: 0.9571 - loss: 0.1619 - val_accuracy: 1.0000 - val_loss: 0.1111 - learning_rate: 5.0000e-04
# Epoch 10/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.1039 - val_accuracy: 1.0000 - val_loss: 0.1088 - learning_rate: 5.0000e-04
# Epoch 11/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - accuracy: 0.9047 - loss: 0.1958
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 32s 583ms/step - accuracy: 0.9052 - loss: 0.1967 - val_accuracy: 1.0000 - val_loss: 0.1001 - learning_rate: 5.0000e-04
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 3.
#
# [Phase 2] Fine-tuning top layers of base model...
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 38s 898ms/step - accuracy: 0.8156 - loss: 0.4011 - val_accuracy: 0.9375 - val_loss: 0.2020 - learning_rate: 1.0000e-04
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.8750 - loss: 0.3535 - val_accuracy: 0.9375 - val_loss: 0.2031 - learning_rate: 1.0000e-04
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 969ms/step - accuracy: 0.8313 - loss: 0.3357 - val_accuracy: 0.9375 - val_loss: 0.2096 - learning_rate: 1.0000e-04
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.7500 - loss: 0.2790 - val_accuracy: 0.9375 - val_loss: 0.2089 - learning_rate: 1.0000e-04
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 16s 771ms/step - accuracy: 0.8876 - loss: 0.2266 - val_accuracy: 0.9375 - val_loss: 0.1904 - learning_rate: 1.0000e-04
# Epoch 6/50
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 10s 545ms/step - accuracy: 0.8750 - loss: 0.3508
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8750 - loss: 0.3508 - val_accuracy: 0.9375 - val_loss: 0.1871 - learning_rate: 1.0000e-04
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 15s 730ms/step - accuracy: 0.8556 - loss: 0.2565 - val_accuracy: 0.9375 - val_loss: 0.1672 - learning_rate: 5.0000e-05
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7500 - loss: 0.4932 - val_accuracy: 0.9375 - val_loss: 0.1657 - learning_rate: 5.0000e-05
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 805ms/step - accuracy: 0.8878 - loss: 0.2687 - val_accuracy: 0.9375 - val_loss: 0.1518 - learning_rate: 5.0000e-05
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 0.0956 - val_accuracy: 0.9375 - val_loss: 0.1500 - learning_rate: 5.0000e-05
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 17s 716ms/step - accuracy: 0.9357 - loss: 0.1810 - val_accuracy: 1.0000 - val_loss: 0.1228 - learning_rate: 5.0000e-05
# Epoch 12/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 1.0000 - loss: 0.0323 - val_accuracy: 1.0000 - val_loss: 0.1211 - learning_rate: 5.0000e-05
# Epoch 13/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 853ms/step - accuracy: 0.9296 - loss: 0.1709 - val_accuracy: 1.0000 - val_loss: 0.1109 - learning_rate: 5.0000e-05
# Epoch 14/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 1.0000 - loss: 0.0617 - val_accuracy: 1.0000 - val_loss: 0.1105 - learning_rate: 5.0000e-05
# Epoch 15/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 15s 707ms/step - accuracy: 0.9504 - loss: 0.1221 - val_accuracy: 1.0000 - val_loss: 0.0976 - learning_rate: 5.0000e-05
# Epoch 16/50
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 10s 520ms/step - accuracy: 0.8750 - loss: 0.2872
# Epoch 16: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.8750 - loss: 0.2872 - val_accuracy: 1.0000 - val_loss: 0.0959 - learning_rate: 5.0000e-05
# Epoch 17/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 16s 721ms/step - accuracy: 0.8792 - loss: 0.2653 - val_accuracy: 1.0000 - val_loss: 0.0855 - learning_rate: 2.5000e-05
# Epoch 18/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 1.0000 - loss: 0.1074 - val_accuracy: 1.0000 - val_loss: 0.0861 - learning_rate: 2.5000e-05
# Epoch 19/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9666 - loss: 0.1356 - val_accuracy: 1.0000 - val_loss: 0.0781 - learning_rate: 2.5000e-05
# Epoch 20/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.6250 - loss: 0.6025 - val_accuracy: 1.0000 - val_loss: 0.0778 - learning_rate: 2.5000e-05
# Epoch 21/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 661ms/step - accuracy: 0.9545 - loss: 0.1187
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 15s 705ms/step - accuracy: 0.9536 - loss: 0.1209 - val_accuracy: 1.0000 - val_loss: 0.0737 - learning_rate: 2.5000e-05
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 11.
#
# Evaluating on validation set...
#
# >>> Fold 8 Accuracy: 1.0000 <<<
#
# ============================================================
# FOLD 9/10
# ============================================================
# Train: 174 samples | Val: 19 samples
# Train distribution - Fracture: 100, Normal: 74
#
# [Phase 1] Training classification head (base frozen)...
# Epoch 1/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 30s 780ms/step - accuracy: 0.6459 - loss: 0.6539 - val_accuracy: 1.0000 - val_loss: 0.3486 - learning_rate: 0.0010
# Epoch 2/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8333 - loss: 0.5871 - val_accuracy: 1.0000 - val_loss: 0.3402 - learning_rate: 0.0010
# Epoch 3/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 16s 592ms/step - accuracy: 0.8865 - loss: 0.2984 - val_accuracy: 0.8750 - val_loss: 0.3259 - learning_rate: 0.0010
# Epoch 4/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 1.0000 - loss: 0.0666 - val_accuracy: 0.8750 - val_loss: 0.3196 - learning_rate: 0.0010
# Epoch 5/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 526ms/step - accuracy: 0.8902 - loss: 0.2182
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 576ms/step - accuracy: 0.8913 - loss: 0.2160 - val_accuracy: 0.8750 - val_loss: 0.2806 - learning_rate: 0.0010
# Epoch 6/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 1.0000 - loss: 0.1267 - val_accuracy: 0.8750 - val_loss: 0.2836 - learning_rate: 5.0000e-04
# Epoch 7/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 992ms/step - accuracy: 0.9489 - loss: 0.1863 - val_accuracy: 0.8125 - val_loss: 0.3299 - learning_rate: 5.0000e-04
# Epoch 8/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8750 - loss: 0.3636 - val_accuracy: 0.8125 - val_loss: 0.3233 - learning_rate: 5.0000e-04
# Epoch 9/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - accuracy: 0.8875 - loss: 0.2394
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 980ms/step - accuracy: 0.8888 - loss: 0.2368 - val_accuracy: 0.8125 - val_loss: 0.2509 - learning_rate: 5.0000e-04
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 1.
#
# [Phase 2] Fine-tuning top layers of base model...
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 37s 863ms/step - accuracy: 0.8160 - loss: 0.4041 - val_accuracy: 1.0000 - val_loss: 0.3149 - learning_rate: 1.0000e-04
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.2048 - val_accuracy: 1.0000 - val_loss: 0.3132 - learning_rate: 1.0000e-04
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 997ms/step - accuracy: 0.8493 - loss: 0.3994 - val_accuracy: 1.0000 - val_loss: 0.2953 - learning_rate: 1.0000e-04
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.7500 - loss: 0.4820 - val_accuracy: 1.0000 - val_loss: 0.2936 - learning_rate: 1.0000e-04
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9359 - loss: 0.2246 - val_accuracy: 1.0000 - val_loss: 0.2751 - learning_rate: 1.0000e-04
# Epoch 6/50
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 11s 565ms/step - accuracy: 0.8750 - loss: 0.3500
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8750 - loss: 0.3500 - val_accuracy: 1.0000 - val_loss: 0.2738 - learning_rate: 1.0000e-04
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 989ms/step - accuracy: 0.9033 - loss: 0.2605 - val_accuracy: 1.0000 - val_loss: 0.2517 - learning_rate: 5.0000e-05
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 1.0000 - loss: 0.0492 - val_accuracy: 1.0000 - val_loss: 0.2504 - learning_rate: 5.0000e-05
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 715ms/step - accuracy: 0.8811 - loss: 0.3764 - val_accuracy: 1.0000 - val_loss: 0.2322 - learning_rate: 5.0000e-05
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 1.0000 - val_loss: 0.2314 - learning_rate: 5.0000e-05
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 690ms/step - accuracy: 0.8828 - loss: 0.3039
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 16s 761ms/step - accuracy: 0.8826 - loss: 0.3048 - val_accuracy: 1.0000 - val_loss: 0.2147 - learning_rate: 5.0000e-05
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
#
# Evaluating on validation set...
#
# >>> Fold 9 Accuracy: 1.0000 <<<
#
# ============================================================
# FOLD 10/10
# ============================================================
# Train: 174 samples | Val: 19 samples
# Train distribution - Fracture: 100, Normal: 74
#
# [Phase 1] Training classification head (base frozen)...
# Epoch 1/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 29s 756ms/step - accuracy: 0.7196 - loss: 0.5586 - val_accuracy: 0.8125 - val_loss: 0.4064 - learning_rate: 0.0010
# Epoch 2/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7500 - loss: 0.3733 - val_accuracy: 0.8125 - val_loss: 0.4002 - learning_rate: 0.0010
# Epoch 3/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 617ms/step - accuracy: 0.8969 - loss: 0.2187 - val_accuracy: 1.0000 - val_loss: 0.2870 - learning_rate: 0.0010
# Epoch 4/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8333 - loss: 0.2818 - val_accuracy: 1.0000 - val_loss: 0.2836 - learning_rate: 0.0010
# Epoch 5/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 19s 605ms/step - accuracy: 0.8639 - loss: 0.3336 - val_accuracy: 1.0000 - val_loss: 0.2925 - learning_rate: 0.0010
# Epoch 6/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - accuracy: 0.8750 - loss: 0.1290 - val_accuracy: 1.0000 - val_loss: 0.2964 - learning_rate: 0.0010
# Epoch 7/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 553ms/step - accuracy: 0.9329 - loss: 0.1431
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 596ms/step - accuracy: 0.9323 - loss: 0.1454 - val_accuracy: 0.8750 - val_loss: 0.3100 - learning_rate: 0.0010
# Epoch 8/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.8750 - loss: 0.2304 - val_accuracy: 0.8750 - val_loss: 0.3075 - learning_rate: 5.0000e-04
# Epoch 9/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 996ms/step - accuracy: 0.9026 - loss: 0.1707 - val_accuracy: 0.9375 - val_loss: 0.2715 - learning_rate: 5.0000e-04
# Epoch 10/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.9375 - val_loss: 0.2704 - learning_rate: 5.0000e-04
# Epoch 11/15
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - accuracy: 0.8584 - loss: 0.3362
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 616ms/step - accuracy: 0.8613 - loss: 0.3291 - val_accuracy: 1.0000 - val_loss: 0.2192 - learning_rate: 5.0000e-04
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 3.
#
# [Phase 2] Fine-tuning top layers of base model...
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 37s 905ms/step - accuracy: 0.9075 - loss: 0.2742 - val_accuracy: 0.9375 - val_loss: 0.2895 - learning_rate: 1.0000e-04
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - accuracy: 0.8750 - loss: 0.3215 - val_accuracy: 0.9375 - val_loss: 0.2893 - learning_rate: 1.0000e-04
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 996ms/step - accuracy: 0.8410 - loss: 0.3295 - val_accuracy: 0.9375 - val_loss: 0.2738 - learning_rate: 1.0000e-04
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 0.8750 - loss: 0.2479 - val_accuracy: 0.9375 - val_loss: 0.2728 - learning_rate: 1.0000e-04
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 15s 726ms/step - accuracy: 0.8827 - loss: 0.2533 - val_accuracy: 0.9375 - val_loss: 0.2461 - learning_rate: 1.0000e-04
# Epoch 6/50
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 11s 559ms/step - accuracy: 0.8750 - loss: 0.1972
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8750 - loss: 0.1972 - val_accuracy: 0.9375 - val_loss: 0.2448 - learning_rate: 1.0000e-04
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 990ms/step - accuracy: 0.9247 - loss: 0.1772 - val_accuracy: 1.0000 - val_loss: 0.2236 - learning_rate: 5.0000e-05
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6250 - loss: 0.6876 - val_accuracy: 0.9375 - val_loss: 0.2232 - learning_rate: 5.0000e-05
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 15s 708ms/step - accuracy: 0.9575 - loss: 0.1276 - val_accuracy: 1.0000 - val_loss: 0.2069 - learning_rate: 5.0000e-05
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8750 - loss: 0.1828 - val_accuracy: 1.0000 - val_loss: 0.2066 - learning_rate: 5.0000e-05
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 990ms/step - accuracy: 0.9501 - loss: 0.1472 - val_accuracy: 1.0000 - val_loss: 0.2019 - learning_rate: 5.0000e-05
# Epoch 12/50
#  1/21 ━━━━━━━━━━━━━━━━━━━━ 11s 564ms/step - accuracy: 0.7500 - loss: 0.2296
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.7500 - loss: 0.2296 - val_accuracy: 1.0000 - val_loss: 0.2021 - learning_rate: 5.0000e-05
# Epoch 13/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 15s 717ms/step - accuracy: 0.9444 - loss: 0.1537 - val_accuracy: 0.9375 - val_loss: 0.1973 - learning_rate: 2.5000e-05
# Epoch 14/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8750 - loss: 0.1499 - val_accuracy: 0.9375 - val_loss: 0.1976 - learning_rate: 2.5000e-05
# Epoch 15/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 19s 710ms/step - accuracy: 0.9504 - loss: 0.1396 - val_accuracy: 0.9375 - val_loss: 0.1882 - learning_rate: 2.5000e-05
# Epoch 16/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8750 - loss: 0.2107 - val_accuracy: 0.9375 - val_loss: 0.1891 - learning_rate: 2.5000e-05
# Epoch 17/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 665ms/step - accuracy: 0.9576 - loss: 0.1410
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 989ms/step - accuracy: 0.9565 - loss: 0.1437 - val_accuracy: 0.8750 - val_loss: 0.1875 - learning_rate: 2.5000e-05
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
#
# Evaluating on validation set...
#
# >>> Fold 10 Accuracy: 1.0000 <<<
#
# ============================================================
# FINAL RESULTS - 10-FOLD CROSS-VALIDATION
# ============================================================
#
# Accuracy per fold:
#   Fold  1: 0.9500 ✓
#   Fold  2: 0.9500 ✓
#   Fold  3: 1.0000 ✓
#   Fold  4: 1.0000 ✓
#   Fold  5: 1.0000 ✓
#   Fold  6: 1.0000 ✓
#   Fold  7: 1.0000 ✓
#   Fold  8: 1.0000 ✓
#   Fold  9: 1.0000 ✓
#   Fold 10: 1.0000 ✓
#
# ────────────────────────────────────────
# Mean Accuracy:  0.9900
# Std Deviation:  0.0200
# Min Accuracy:   0.9500
# Max Accuracy:   1.0000
# ────────────────────────────────────────
#
# Overall Classification Report:
#               precision    recall  f1-score   support
#
#       Normal     0.9878    0.9878    0.9878        82
#     Fracture     0.9910    0.9910    0.9910       111
#
#     accuracy                         0.9896       193
#    macro avg     0.9894    0.9894    0.9894       193
# weighted avg     0.9896    0.9896    0.9896       193
#
# Confusion Matrix:
#                   Predicted
#                 Normal  Fracture
# Actual Normal       81        1
#        Fracture      1      110
#
# ============================================================
# GRADE CALCULATION
# ============================================================
#
# 10-Fold CV Mean Accuracy: 0.9900
# Grade: 15/15 points (FULL GRADE)
# ✓ Accuracy >= 0.95: Requirement met!
#
# ============================================================
# EXECUTION COMPLETED
# ============================================================
